# %% [markdown]
# # 04 Ordinal Encoder by OrdinalEncoder class import and map function both

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Size':['s','m','l','xl','s','m','s','s','l','xl','m']})
df.head(3)
# Out:
#   Size
# 0    s
# 1    m
# 2    l

# %%
ord_data = [['s','m','l','xl']]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=ord_data)
oe.fit(df[['Size']])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
df['Size_en'] = oe.transform(df[['Size']])
df
# Out:
#    Size  Size_en
# 0     s      0.0
# 1     m      1.0
# 2     l      2.0
# 3    xl      3.0
# 4     s      0.0
# 5     m      1.0
# 6     s      0.0
# 7     s      0.0
# 8     l      2.0
# 9    xl      3.0
# 10    m      1.0

# %% [markdown]
# # By Map Function

# %%
ord_data1 = {'s':2,'m':3,'l':4,'xl':5}
df['Size_en_map'] = df['Size'].map(ord_data1)
df
# Out:
#    Size  Size_en  Size_en_map
# 0     s      0.0            2
# 1     m      1.0            3
# 2     l      2.0            4
# 3    xl      3.0            5
# 4     s      0.0            2
# 5     m      1.0            3
# 6     s      0.0            2
# 7     s      0.0            2
# 8     l      2.0            4
# 9    xl      3.0            5
# 10    m      1.0            3

# %%
dataset = pd.read_csv('loan.csv')
dataset.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
dataset['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
en_data_ord = [['Urban', 'Rural', 'Semiurban']]

# %%
oen = OrdinalEncoder(categories=en_data_ord)

# %%
dataset['Property_Area'] = oen.fit_transform(dataset[['Property_Area']])
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0            0.0           Y
# 1             1.0            1.0           N
# 2             1.0            0.0           Y
# 3             1.0            0.0           Y
# 4             1.0            0.0           Y
