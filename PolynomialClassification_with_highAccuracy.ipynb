# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset2 = pd.read_csv('polynomial_classification_data.csv')
dataset2.head()
# Out:
#        data1     data2  output
# 0 -10.000000  0.792378       0
# 1  -9.797980  0.295467       0
# 2  -9.595960  0.494191       0
# 3  -9.393939  0.730681       0
# 4  -9.191919 -0.347837       0

# %%
x = dataset2.drop(columns=['output'])
y= dataset2['output']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures(degree=2)
pf.fit(x)
# Out:
# PolynomialFeatures()

# %%
x = pd.DataFrame(pf.transform(x))
x
# Out:
#      0    1          2         3           4         5         6    7   \
# 0   1.0  1.0 -10.000000  0.792378  100.000000 -7.923782  0.627863  1.0
# 1   1.0  1.0  -9.797980  0.295467   96.000408 -2.894976  0.087301  1.0
# 2   1.0  1.0  -9.595960  0.494191   92.082441 -4.742238  0.244225  1.0
# 3   1.0  1.0  -9.393939  0.730681   88.246097 -6.863975  0.533895  1.0
# 4   1.0  1.0  -9.191919 -0.347837   84.491378  3.197287  0.120990  1.0
# ..  ...  ...        ...       ...         ...       ...       ...  ...
# 95  1.0  1.0   9.191919 -0.500997   84.491378 -4.605128  0.250998  1.0
# 96  1.0  1.0   9.393939  0.178894   88.246097  1.680518  0.032003  1.0
# 97  1.0  1.0   9.595960 -0.039819   92.082441 -0.382103  0.001586  1.0
# 98  1.0  1.0   9.797980 -0.362042   96.000408 -3.547280  0.131074  1.0
# 99  1.0  1.0  10.000000 -0.661315  100.000000 -6.613147  0.437337  1.0
#
#            8         9   ...        18         19        20        21  \
# 0  -10.000000  0.792378  ...  0.627863  79.237819 -6.278632  0.497505
# 1   -9.797980  0.295467  ...  0.087301  28.364913 -0.855369  0.025794
# 2   -9.595960  0.494191  ...  0.244225  45.506323 -2.343572  0.120694
# 3   -9.393939  0.730681  ...  0.533895  64.479769 -5.015378  0.390107
# 4   -9.191919 -0.347837  ...  0.120990 -29.389208 -1.112134 -0.042085
# ..        ...       ...  ...       ...        ...       ...       ...
# 95   9.191919 -0.500997  ...  0.250998 -42.329961  2.307157 -0.125750
# 96   9.393939  0.178894  ...  0.032003  15.786681  0.300634  0.005725
# 97   9.595960 -0.039819  ...  0.001586  -3.666649  0.015215 -0.000063
# 98   9.797980 -0.362042  ...  0.131074 -34.756180  1.284264 -0.047454
# 99  10.000000 -0.661315  ...  0.437337 -66.131468  4.373371 -0.289217
#
#               22          23         24         25        26        27
# 0   10000.000000 -792.378187  62.786319  62.786319 -4.975051  0.394212
# 1    9216.078360 -277.918840   8.380884   8.380884 -0.252733  0.007621
# 2    8479.175861 -436.676834  22.488820  22.488820 -1.158172  0.059646
# 3    7787.373695 -605.719039  47.114158  47.114158 -3.664643  0.285044
# 4    7138.793029  270.143221  10.222647  10.222647  0.386841  0.014639
# ..           ...         ...        ...        ...       ...       ...
# 95   7138.793029 -389.093579  21.207200  21.207200 -1.155880  0.063000
# 96   7787.373695  148.299127   2.824140   2.824140  0.053782  0.001024
# 97   8479.175861  -35.185013   0.146003   0.146003 -0.000606  0.000003
# 98   9216.078360 -340.540352  12.583197  12.583197 -0.464958  0.017181
# 99  10000.000000 -661.314678  43.733710  43.733710 -2.892174  0.191264
#
# [100 rows x 28 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
lr.score(x_test, y_test) * 100
# Out:
# C:\Users\ACER\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100.0
